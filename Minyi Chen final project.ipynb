# %% [markdown]
# ### ALY6983 Python for Data Science
# ### Instructor: Joel Schwartz
#
# ### Final Project: Create Word Cloud from .txt File
# ### Minyi Chen
# ### July 1, 2018
#
#
#
# ### Overview
#
# In this final project, I generate wordcloud graph for .txt file. I use the tip text of resturant Meat & Potatoes in Pittsburgh, PA as an example to show you how it works. The data is from Yelp Dataset. I wrote two main functions: clean(text) and create_wordcloud(text) to clean and generate wordcloud of a text file.
#
# A tsunami of data is generated by the Internet and social media. Being able to use Natural Language Processing (NLP) to uncover the insights of this unstructured data is valuable and interests me. Thus, I pick wordcloud generating as my final project and also the start of learning NLP.
#
#
#
# ### Part 1. Prepare the data
#
# Go to https://www.yelp.com/dataset/challenge, download the json dataset. After downloading, you will have 2.7G .tar format in your computer (.tar means double compressed). You can get free 7 zip here: https://www.7-zip.org/. Use 7 zip to unzip the .tar file, then you get a 6.07GB file. Change the extension of this file to .tar, and then unzip it again. Finally, you get several json files in the folder. The explanation of each json file is here: https://www.yelp.com/dataset/documentation/json. The size of each json is 1) business.json 138mb, 2) checkin.json 60.3mb, 3) photos.json 25.6mb, 4) review.json 3.9GB, 5) tip.json 188mb, 6) user.json 1.76GB. These datasets are prepared for the Yelp_Dataset_Challenge_Round_11, runing from January 18, 2018 to June 30, 2018.
#
# In order to get the review texts for resturant Meat&Potatoes in Pittsburgh, PA, I need business.json and tip.json files. Review dataset is too big for me to run, so I pick tip dataset that includes short review texts of resturants.
#
# IMPORTANT NOTE:
# I will provide you the txt file, so you don't need to prepare the data. I will also provide you the codes to show you how I get the txt file. However, business.json and tip.json are too big to upload. So you cannot run the codes of this part unless you actually have the files from Yelp. What you need to do is to download the meatpotato.txt directly from Github. I will remind you later before running the codes.
#
#
# ### Part 2. Clean the text functions
#
# In order to do further analysis on text file using deep learning or machine learning model, you need to clean the text file first which means split the text into words with some cleaning. Here, I do basic cleaning of the text: strip white spaces, turn all words into lowercase, tokenize text, remove puntuation, remove stopwords, and stem words.
#
# 1) strip whitespaces.
# This will remove the white spaces in the text.
#
# 2) lowercase text.
# This will turn letters into lowercase. For example, turn Hi into hi, I into i. The reason I need to do this is because the stopwords are all in lowercase such as i. I want to remove stopwords, so I need to turn my words in the text into lowercase.
#
# 3) tokenize text.
# This will break your text up into individual words. This step is important because it turns the text into data for us to analyze later.
#
# 4) remove puntuation.
# This will only keep letters, so it will remove the puntuation such as "." "," "!", numbers, etc.
#
# 5) remove stopwords.
# This will remove the extremely common words (called "stopwords") such as me, my, did, a, the. These words don't give us much information, so we want to remove them. We need to do this for tokenized words.
#
# 6) Stem words.
# This will make some words into the same word, their root form. For example, turn waiting/waited/waits into wait. However, it doesn't do a good job in my case as you will see soon. For example, it will turn fries into fri, which changes the original meaning. Thus, I keep this out of my function clean(), and define a seperate function for it. We also need to do this for tokenized words.
#
#
# Python has several built-in functions associated with the string data type. We can use this functions to do some basic cleaning: strip whitespaces (string.strip()), lowercase text (string.lower()), remove puntuation/keep all letters (string.isalpha()). Then we use nltk (natural language toolkit) packages to tokenize text, remove stopwords, and stem words.
#
#
# References:
# https://machinelearningmastery.com/clean-text-machine-learning-python/
#
#
#
#
# ### Part 3. Create word cloud function
#
# Use wordcloud packages to create wordcloud graph for the cleaned text and the original text. One special thing I do for the word cloud is that I change the mask of the default wordcloud. In my case, I pick a cow picture to make the wordcloud looks like a cow. I pick cow picture because there is a cow on the resturant Meat&Potatoes website http://www.meatandpotatoespgh.com/.
#
# More info about wordcloud: https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

# %% [markdown]
# ### GET START

# %%
# In Anaconda prompt, install these first
# pip install nltk
# pip install wordcloud

# Then,
import pandas as pd  # data structures and data analysis tools 
import numpy as np #for scientific computing 
import matplotlib.pyplot as plt  #for plots
import os #provides a way of using operating system dependent functionality
import imageio # read images
import nltk  # natural language toolkit
from nltk import word_tokenize  
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator # create wordcloud

# %%
# To check your current working directory (cwd)
os.getcwd()
# Out:
# 'C:\\Users\\minyi'

# %% [markdown]
# ### Part 1. Prepare the data
#
# ### (You don't need to run this part)  #################################
#
# ### (This part is to show you how I get the meatpotato.txt file which you download it from GitHub)

# %%
# Put business.json & tip.json file in the directory
# Read the tip.json file as dataframe and show the first 3 rows
# The columns incldue business_id, date, likes, text, and user_id
# We only need business_id and text columns
# lines=true means that read the file line by line
df1= pd.read_json('tip.json', lines=True)
df1.head(3)
# Out:
#               business_id       date  likes  \
# 0  tJRDll5yqpZwehenzE2cSg 2012-07-15      0
# 1  jH19V2I9fIslnNhDzPmdkA 2015-08-12      0
# 2  dAa0hB2yrnHzVmsCkN4YvQ 2014-06-20      0
#
#                                                 text                 user_id
# 0              Get here early enough to have dinner.  zcTZk7OG8ovAmh_fenH21g
# 1  Great breakfast large portions and friendly wa...  ZcLKXikTHYOnYt5VYRO5sg
# 2  Nice place. Great staff.  A fixture in the tow...  oaYhjqBbh18ZhU0bpyzSuw

# %%
# Read the business.json file as dataframe and show the first 3 rows
# We can see the file includes columns: business_id, categories, city, name, stars, state, etc.
df2= pd.read_json('business.json', lines=True)
df2.head(3)
# Out:
#                     address  \
# 0  4855 E Warner Rd, Ste B9
# 1        3101 Washington Rd
# 2    6025 N 27th Ave, Ste 1
#
#                                           attributes             business_id  \
# 0  {'AcceptsInsurance': True, 'ByAppointmentOnly'...  FYWN1wneV18bWNgQjJ2GNg
# 1  {'BusinessParking': {'garage': False, 'street'...  He-G7vWjzVUysIKrfNbPUQ
# 2                                                 {}  KQPW8lFf1y5BT2MxiSZ3QA
#
#                                           categories       city  \
# 0  [Dentists, General Dentistry, Health & Medical...  Ahwatukee
# 1  [Hair Stylists, Hair Salons, Men's Hair Salons...   McMurray
# 2  [Departments of Motor Vehicles, Public Service...    Phoenix
#
#                                                hours  is_open   latitude  \
# 0  {'Friday': '7:30-17:00', 'Tuesday': '7:30-17:0...        1  33.330690
# 1  {'Monday': '9:00-20:00', 'Tuesday': '9:00-20:0...        1  40.291685
# 2                                                 {}        1  33.524903
#
#     longitude                   name neighborhood postal_code  review_count  \
# 0 -111.978599       Dental by Design                    85044            22
# 1  -80.104900    Stephen Szabo Salon                    15317            11
# 2 -112.115310  Western Motor Vehicle                    85017            18
#
#    stars state
# 0    4.0    AZ
# 1    3.0    PA
# 2    1.5    AZ

# %%
# See the top 15 most reviewed businesses which are all in Las Vegas
# In the code, we first select the columns in the data set,
# and then sort the review_count number from large to small
df2[['name','categories','city','state','review_count','stars']].sort_values(ascending = False,by='review_count')[0:15]
# Out:
#                                     name  \
# 97944                       Mon Ami Gabi
# 119907                  Bacchanal Buffet
# 69993                       Wicked Spoon
# 81212                Gordon Ramsay BurGR
# 139699                  Earl of Sandwich
# 19191                 Hash House A Go Go
# 80590                         The Buffet
# 124412                     Lotus of Siam
# 21006                      Serendipity 3
# 93038             The Buffet at Bellagio
# 26748               ARIA Resort & Casino
# 80626      The Cosmopolitan of Las Vegas
# 25096                       Secret Pizza
# 6670    Luxor Hotel and Casino Las Vegas
# 6782        Bouchon at the Venezia Tower
#
#                                                categories       city state  \
# 97944   [French, Steakhouses, Restaurants, Breakfast &...  Las Vegas    NV
# 119907  [Sandwiches, Buffets, Restaurants, Breakfast &...  Las Vegas    NV
# 69993          [Buffets, Breakfast & Brunch, Restaurants]  Las Vegas    NV
# 81212      [American (Traditional), Burgers, Restaurants]  Las Vegas    NV
# 139699  [Caterers, Sandwiches, Restaurants, Food Deliv...  Las Vegas    NV
# 19191   [American (New), Restaurants, Breakfast & Brunch]  Las Vegas    NV
# 80590                              [Buffets, Restaurants]  Las Vegas    NV
# 124412  [Car Dealers, Thai, Automotive, Seafood, Bars,...  Las Vegas    NV
# 21006   [Social Clubs, Arts & Entertainment, American ...  Las Vegas    NV
# 93038              [Buffets, Restaurants, American (New)]  Las Vegas    NV
# 26748   [Event Planning & Services, Arts & Entertainme...  Las Vegas    NV
# 80626   [Hotels, Event Planning & Services, Casinos, H...  Las Vegas    NV
# 25096                                [Pizza, Restaurants]  Las Vegas    NV
# 6670    [Event Planning & Services, Arts & Entertainme...  Las Vegas    NV
# 6782    [Breakfast & Brunch, Venues & Event Spaces, Ev...  Las Vegas    NV
#
#         review_count  stars
# 97944           7361    4.0
# 119907          7009    4.0
# 69993           5950    3.5
# 81212           5447    4.0
# 139699          4869    4.5
# 19191           4774    4.0
# 80590           4018    3.5
# 124412          3964    4.0
# 21006           3910    3.0
# 93038           3838    3.5
# 26748           3794    3.5
# 80626           3772    4.0
# 25096           3741    4.0
# 6670            3621    2.5
# 6782            3570    4.0

# %%
# See the top 4 most reviewed businesses in Pittsburgh with 4.5 star
df2[(df2['city'] == 'Pittsburgh') & (df2['stars'] == 4.5)].sort_values("review_count", ascending=False)[0:4]
# Out:
#                    address                                         attributes  \
# 36476        1601 Penn Ave  {'RestaurantsTableService': False, 'GoodForMea...
# 15487   242 S Highland Ave  {'RestaurantsTableService': True, 'GoodForMeal...
# 174433          214 6th St  {'RestaurantsTableService': True, 'GoodForMeal...
# 7282            212 6th St  {'Alcohol': 'full_bar', 'HasTV': False, 'Noise...
#
#                    business_id  \
# 36476   u4sTiCzVeIHZY8OlaL346Q
# 15487   dLc1d1zwd1Teu2QED5TmlA
# 174433  woXlprCuowrLJswWere3TQ
# 7282    SmkYLXEYhzwUZdS6TAevHg
#
#                                                categories        city  \
# 36476   [Argentine, Seafood, Restaurants, Latin American]  Pittsburgh
# 15487                        [Restaurants, Noodles, Thai]  Pittsburgh
# 174433             [Mexican, American (New), Restaurants]  Pittsburgh
# 7282    [Nightlife, Bars, Restaurants, Cocktail Bars, ...  Pittsburgh
#
#                                                     hours  is_open   latitude  \
# 36476   {'Tuesday': '11:00-21:00', 'Friday': '11:00-22...        1  40.449043
# 15487   {'Monday': '12:00-22:00', 'Tuesday': '12:00-22...        1  40.457748
# 174433  {'Monday': '17:00-23:00', 'Tuesday': '17:00-23...        1  40.442229
# 7282    {'Tuesday': '17:00-23:00', 'Friday': '17:00-0:...        1  40.442334
#
#         longitude                       name    neighborhood postal_code  \
# 36476  -79.987573  Gaucho Parrilla Argentina  Strip District       15222
# 15487  -79.925494                 Noodlehead       Shadyside       15206
# 174433 -80.001985                       täkō        Downtown       15222
# 7282   -80.002066        Butcher and the Rye        Downtown       15222
#
#         review_count  stars state
# 36476           1267    4.5    PA
# 15487            820    4.5    PA
# 174433           806    4.5    PA
# 7282             677    4.5    PA

# %%
# see the top 4 most reviewed businesses in Pittsburgh with 4 star
df2[(df2['city'] == 'Pittsburgh') & (df2['stars'] == 4)].sort_values("review_count", ascending=False)[0:4]
# Out:
#                  address                                         attributes  \
# 130495      649 Penn Ave  {'RestaurantsTableService': True, 'GoodForMeal...
# 3182    1805 E Carson St  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 76284       942 Penn Ave  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
# 135266  1150 Smallman St  {'Alcohol': 'full_bar', 'HasTV': True, 'NoiseL...
#
#                    business_id  \
# 130495  JLbgvGM4FXh9zNP4O5ZWjQ
# 3182    LQFmktF43j2NPncKdNd9mg
# 76284   sMzNLdhJZGzYirIWt-fMAg
# 135266  d2ZQRjuizstCTnicysmpMQ
#
#                                                categories        city  \
# 130495  [Specialty Food, Steakhouses, Meat Shops, Amer...  Pittsburgh
# 3182    [Restaurants, Bars, Nightlife, American (Tradi...  Pittsburgh
# 76284   [Cocktail Bars, American (New), Nightlife, Ita...  Pittsburgh
# 135266                      [Restaurants, American (New)]  Pittsburgh
#
#                                                     hours  is_open   latitude  \
# 130495  {'Monday': '17:00-23:00', 'Tuesday': '17:00-23...        1  40.443145
# 3182    {'Monday': '11:00-0:00', 'Tuesday': '11:00-0:0...        1  40.428967
# 76284   {'Monday': '11:00-22:00', 'Tuesday': '11:00-22...        1  40.443950
# 135266  {'Monday': '11:30-22:00', 'Tuesday': '11:30-22...        1  40.446002
#
#         longitude              name    neighborhood postal_code  review_count  \
# 130495 -80.001104   Meat & Potatoes        Downtown       15222          1476
# 3182   -79.980176  Fat Heads Saloon      South Side       15203           657
# 76284  -79.996437    Sienna Mercato        Downtown       15222           632
# 135266 -79.993500            Eleven  Strip District       15222           572
#
#         stars state
# 130495    4.0    PA
# 3182      4.0    PA
# 76284     4.0    PA
# 135266    4.0    PA

# %%
# Prepare txt file
# Meat & Potatoes business_id: JLbgvGM4FXh9zNP4O5ZWjQ
# Select the text that are from Meat & Potatoes to new dataframe
# Keep the text column only
# Save the new dataframe to meatpotato.txt
# then you will find a meatpotato.txt file in your directory
df1n = df1[(df1['business_id'] == 'JLbgvGM4FXh9zNP4O5ZWjQ')]
df1n1 = df1n["text"].to_csv("meatpotato.txt", header=False)

# %% [markdown]
# ### Part 2. Clean the text
#
# ### Please download meatpotato.txt and cow.jpg, and put them in your directory before you proceed

# %%
# Read txt file
# 'r' means open a text file and then read from the file
# read() means the contents of the file are copied into the text as string
# print() the contents of the text
mp = open('meatpotato.txt','r').read()
print(mp)
# Out:
# 645,Didn't think I would need a reservation on a Sunday. I was wrong.
# 1125,A foodie must. Stop in and try the small plates and specialty cocktails on your way around the cultural district. Or take a date for dinner.
# 3602,Bloody Mary bar....JERK vodka! I mean that in the best sense of 'jerk' of course!
# 3603,Now THIS is the way to do Lenten Fridays!
# 3604,Ribs! Smoked for hours and hours right out back....nice.
# 3708,Best Brunch in Da Burgh!
# 4412,These guys fill up fast and it gets noisy real quick - make a reservation and go early if you can!
# 4663,A great drink selection and a unique menu
# 5818,Om nom nom
# 5819,Quick dinner before Van Halen
# 5820,Love the bone marrow and the tartare.
# 5948,Make a reservation! This place is busy even on a Sunday night.
# 6007,"Probably the most epic Bloody Mary bar of all time! Oh, and I must also mention that there is one for the bellinis!!"
# 6702,Heard a lot of good things - meeting brother and sis for dinner :-)
# 6703,Really good burger - bun is very good - made in house.  Fries are excellent.  AV wild turkey stout is yummy
# 7394,Convenient street and garage parking around the corner
# 7772,Lunch hours now start at 11:30!
# 10207,Pub burger France 75 short rib hash irish breakfast tater n truffle mayo. BRUNCH! :)
# 10550,Work lunch. Got the black and blue burger. It was Epic!
# 10551,Sunday Brunch.
# 11197,I am in love with this place!!
# 11198,"Sadly, brunch has been my least favorite visit here. Subpar service, gnats. Bloody Mary bar & food are still good though!"
# 11199,Food is off the chart tonight!
# 11611,Try an old school cocktail.
# 12293,Mmmmm
# 12294,Bone marrow and charcuterie .....yummmo.
# 12385,A taste of Absinthe...
# 12386,Trying a Blood & Sand to start!
# 12907,Random but they have wifi! Extremely comfy chairs
# 13187,Brunch!
# 13188,The French Toast is cooked in Well's Banana Bread Beer!
# 13189,First day of lunch!
# 13190,Tequila Fizz is so refreshing!
# 13191,Now serving lunch!
# 13192,Bloody Mary Bar!!
# 13193,First time here!
# 13417,Bloody Mary's
# 13722,I spent $59 on a 34 oz ribeye with NO FLAVOR...!! No wonder they have steak sauce :(
# 13845,"Kinda loud, apparently you need reservations weeks in advance but we just walked in. P.s. they need to fix their couch and dust it off though..."
# 14339,Mussels!
# 15241,Restaurant week!
# 15710,Brunch!
# 15711,Linda and I are the first regular lunch customers!
# 15867,These bartenders make some excellent beverages! Oww!
# 15886,Virtually empty for Sunday brunch! Taking a while to get our food though. :-/
# 16000,So many delicious options. Must come back.
# 16001,Make reservations. Always!
# 16798,Make a reservation!!
# 16960,Definitely try the libations! Amazing!
# 17292,Bone marrow...don't be afraid to step out of your comfort zone and give this deliciousness a try!
# 17347,No longer offering lunch on weekdays :(
# 17718,Boom!
# 18945,Their service has really gone downhill over the years.
# 19142,"Make reservations and order one of their speciality drinks. Dinner options offer variety, try their roasted chicken. YUM!"
# 19472,Buttermilk fried chicken livers and 34 oz Ribeye (for 2)
# 20335,$5 bloody mary bar for brunch! Great vodka and tequila infusion options
# 20495,Pub burger and an Anderson's Hop Ottin' IPA is the answer here.
# 20519,My most favorite drinking and eating place. LOVE Meat & Potatoes!
# 20556,You have to try the Mac and cheese!!!!
# 20794,Ha
# 20850,And we are back for drinks after the show!
# 20936,"Very loud at night. My date and I had to lean over our table to talk. Quieted down around 9:45 though. Awesome food, truely floored. Get the delicious sour at the bar! So great"
# 20961,Fried Brussels sprouts!! Trust me
# 22388,The atmosphere and menu are unbeatable if youre a rugged gentleman
# 22389,"Inner quote: ""it's like, what am i going to do after this?  Just go home and back to my mundane life.  I just want to live in eternity ere, eating bone marrow"""
# 22945,"""Hip & Trendy"" does not always mean you'll have a great night. Less then impressed with all of their culinary trickery. Simple is better. I would have thought being named Meat & Potatoes they'd get that. Go for happy hour. Leave before dinner."
# 23538,"Get a bar seat, no wait time and more entertaining."
# 24210,Cool vibe
# 24671,"Wow, it was hard to choose.  No meat or potatoes for me tonight, but I will be back."
# 24766,"Smoked wings and 21st Amendment Back in Black, with a koozie"
# 24897,Laughter is the best medicine. But champagne gets the job done faster!
# 24940,"So good for weekend brunch! They just started serving lunch Feb.24, Fridays only though..."
# 25273,"Chicken and waffles and peanut butter monkey bread with a make-your-own bloody mary bar. The BEST fried chicken I have had, hands down."
# 25459,Come for 5$ Bloody Mary bar...
# 25460,Eat the specials. They are always great.
# 26052,Make sure ya call for a reservation! Went here on a Wednesday night for my birthday and it was packed! So glad we had reservation though :)
# 26130,Great place for a Sunday brunch. Sat at the bar with great service and great food (& of course an Irish breakfast coffee)
# 26532,"Crazy good food esp for foodies and crazy good see cow. Thanks, Emily!"
# 26738,brunch and drinks from my favorite place!
# 26739,birthday celebration!
# 26740,love Adam and mike ;) fabulous drinks. great service everytime! busy and gets packed - quickly find a good seat at the bar or call!
# 27787,Amazing brunch
# 27791,"Amazing!  Brunch, lunch, dinner, and cocktails.  Meat & Potatoes never fails you."
# 27894,Turn down for what?! This Absinthe is on fire
# 27908,"Fathers Day Celebration, enjoying the Bloody Mary Bar and the unique brunch menu"
# 28209,It was good. A good place to hangout. Tried salmon it was good.
# 28230,Unlimited bloody mary bar for $15!!! Only in Pittsburgh.
# 28449,Food was strangely good! Service was ok too.
# 28916,Make sure you make a reservation!
# 29273,Brunch is the best!
# 29680,The three pigs sandwich is a must try!
# 29708,Make reservation!
# 30733,Had brunch twice. Great experience both times. Very talented staff.
# 43689,Fried brussels are where it's at!
# 45771,The get a table process is wack! Way over engineered especially when there are visible tables available.
# 58084,This place has amazing wings. And the pork chop dish is eye popping as well as delicious. Bring an empty stomach!
# 88922,because we're men
# 93118,If you're at the bar-highly recommended- let the bartenders hook you up with drinks and food. Ye shall be rewarded!
# 102352,Brunch
# 102760,Wow! amazing! feels fancy yet warm and comfy without being redneck like back home in deep south! Seriously some of the BEsT BBQ and food and service around Pittsburgh! love these people here and food! Thanks for a wonderful night again!
# 237599,"Eclectic menu, looks fun, here we go!"
# 476933,Come hungry!
# 580224,Come see Mike at the bar - a wizard of cocktails.  Inventive menu.
# 580254,Visited once as I've been craving to go back. Food was fantastic!
# 580735,Place is amazing!!! You have to eat there!
# 581394,Should I get Poutine?
# 581781,Gluten free and vegan options on their lenten menu!
# 582114,Love this places' atmosphere and thier macaroni and cheese :)
# 582700,"Get the bread pudding,  they make it with banana bread."
# 582926,Get the bone marrow. It is big enough to share.
# 583470,"Damn, that old fashioned is fresh"
# 583471,Sgt Pepper Old Fashioned can get it. Yaaas bourbon!
# 595578,"Oh my, the cocktails!!"
# 605454,"Love the decor, rustic and chic!"
# 702380,Pioneering restaurant and an inspiration to all else that is trendy and delicious.
# 707891,"If you don't order the bone marrow, you're an idiot."
# 707924,The food is amazing! The only flip side is the tiny seating. You almost always end up talking to your neighbor.
# 711494,Everything was delicious
# 723230,Wings fried Brussel sprouts martini good atmosphere. Great bar. Younger hang
# 787328,I just had the rudest experience in a bar in Pittsburgh ever!!  The bartenders are just mean.
# 787738,Phenomenal dinner entrees
# 792450,"Great food, good atmosphere, always interesting specials to consider, random beer selection changes daily."
# 807723,Dine outside even though it's chilly? Each seat has a small blanket to help you warm yourself. How thoughtful!
# 807800,Up in smoke is a great cocktail. And the Brussel sprouts are great too'
# 825884,"If ordering the ribeye for 2 people, I suggest not ordering anything except drinks. It comes with a piece of marrow so it basically comes with an appetizer."
# 903092,Brunch Salmon Flat Bread!
# 904575,Ladies - Try the black dog and thank me later.
# 929589,Bad service... mediocre food. I would never waste my time here again.
# 929782,Awesome food. Nuff said
# 931291,"Come early, make reservations, politely ask for your 34oz ribeye with everything on the side. Why they would top it with anything surprises me. My guess for this price it's unaged prime. Try the bloody mary bar."
# 966522,Make reservations for early it's a bit easier to get a table
# 977931,On the weekend come between 7-8 to grab a bar seat if you don't have reservation
# 984555,This place is awesome! Def with checking out!!
# 984556,Yum! Punch. Fried brussel sprouts. Steak tartare
# 984557,Great brunch!  Recommend the corned beef Benedict.  Add spice to the bloody Mary's though.
# 984558,Awesome lunchtime spot. Great atmosphere and huge portions.
# 984559,I visited last night on New Year's Eve and ordered the fried pickles (my fave). They took almost 45 mins.  The waitress also didn't offer an explanation or offer to refill our drinks while we waited.  The table next to us ordered them as well and they were delivered in 10 mins.  Very disappointed.
# 984560,Place looks awesome.
# 984561,Veuve and fried pickles.
# 984562,"Hello Meat and Potatoes Restaurant, Can you please add seasoning to your dishes? Thank you."
# 984564,Worst service ever. Totally rude staff. Don't go.
# 984565,"Highly overrated
# Great Mac n Cheese
# Tuna tacos were terribly salty and inedible
# Salmon was cooked perfectly but kimchi took away from flavor"
# 984566,"Soo good!!! Love the Bone marrow, yummmmm. Deff should try if in Pittsburgh."
# 984567,"The tartare was my favorite appetizer.  I like bone marrow, however to have to add thr toppings each time doesnt it make it enjoyable.  I've had better.  The pate was a bit sweet for my taste."
# 984568,The meat and potatoes for two is enough for 3
# 984569,Be ready for an amazing meal & extremely tasty Cocktails.
# 984570,They crammed a lot of tables near the bar area
# 984571,"Make a reservation or eat at the bar.   The bartenders can make anything to drink, I mean anything."
# 984572,Absinthe and amazing steak!
# 984573,"When sitting at the bar, wave your arm so they acknowledge your presence. M&P has gotten cocky and full of themselves."
# 984574,"Great service, pot roast was incredible, and pork belly tacos"
# 984575,Bartenders could be much friendlier!
# 984576,make reservations
# 984577,See check in comments. ......
# 984578,Amazing food... Good service.  Will definitely be coming back. Best Caesar salad.
# 984579,Food was lukewarm but tasted sensational.
# 984581,Great food but avoid during busy times (Friday & Saturday Nights). The wait staff gets overwhelmed easily and the service goes downhill. But seriously great food!
# 984582,"If in the bar area, service is much better from bartenders versus section waiters."
# 984585,Nice atmosphere although tight quarters.  Food and drinks were great.
# 984586,Does what it says in the name and does it well. Stellar steak and friendly service.
# 984587,Highly recommend the short ribs.
# 984588,Try the Tomahawk Ribeye from the best steak in America.
# 984589,"Nice fusion cuisine, the bibimbap is a must!"
# 984590,See check in comment
# 984591,Very busy place. Make a reservation
# 984592,That duck though! Worth a blown paycheck for that tomahawk!
# 984593,Pastrami rubbed pork belly... That is all.
# 984594,Love this place.  Chicken livers are outstanding and the bone marrow is a must.
# 984595,Always great.
# 984596,"No valet parking.
#
# Chicken & Waffles are only on the lunch menu."
# 984597,Atmospherically be prepared to feel like you're eating in the middle of a Hollister retail store with the brain thumping bass and mindless house music in the background. Just a tad too much for Sunday brunch.
# 984598,"Really good drinks, and probably the best mussels in town!"
# 984599,"A little wait, but Outstanding food."
# 984600,Don't eat at Meat and Potatos in Pittsburgh the staff is RUDE!!!
# 984601,Started out with rude bartender. He softened a bit but seriously!  Pittsburgh will never change. Just another pig with lipstick!
# 984602,Meat and Potatoes for Two changes lives.
# 984603,Love it here! I dream of their cheese plate!!!
# 984604,CXC aallyl
# 984605,Always make this a stop! Great late night eats!
# 984606,Cool space with fun vibe. Thai steak salad was delish and service was pleasant.
# 984607,"One of my favorite places
# Great service, amazing food"
# 984610,"The brunch is spectacular, and the bloody marries are even better!"
# 984611,"If you order the Chicken and Waffles for brunch, don't plan on eating for the rest of the day!"
# 984615,My favorite restaurant in Pittsburgh. Great go to spot and always on point!
# 984616,"Great drinks, and the Burger was one of the best I have ever had."
# 984617,Always a meal that never disappoints.
# 984618,This place is outstanding! Great atmosphere and the food was superb.
# 984619,The food was great and the atmosphere kept me there for another drink.
# 984620,The special yellow tomato gazpacho with blue crab was outstanding! I liked it  so much that I had a bowl as an appetizer and another for dinner! Bravo chef!
# 984621,Great meat and appetizers. I love the drinks.  A good place to go after the theater.

# %%
# Download the stopwords from nltk package, and load the stop words in English
# You can see the lists of the stopwords in english
nltk.download("stopwords")
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\minyi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# define function clean() to do the basic text cleaning
# strip white space, lowercase, tokenize, remove puntuation/only keep letters, remove stopwords
# Python has several built-in functions associated with the string data type:
# strip whitespaces (string.strip()), lowercase text (string.lower()), 
# remove puntuation/keep all letters (string.isalpha()). 
# Then we use nltk (natural language toolkit) packages to tokenize text, remove stopwords
def clean(text):
    stripwhitespace= text.strip()
    lowercase= stripwhitespace.lower()
    tokenize = nltk.word_tokenize(lowercase)
    no_puntuation = [word for word in tokenize if word.isalpha()] # only keep letters in the tokenize
    stop = stopwords.words('english') # save the stopwords in stop
    result_text = [word for word in no_puntuation if word not in stop] # get the text that is in the no_puntuation, but not in the stop
    return result_text

# %%
# clean our text
# You can see the text are cleaner than the original one and they are tokenized
clean(mp)
# Out:
# ['think',
#  'would',
#  'need',
#  'reservation',
#  'sunday',
#  'wrong',
#  'foodie',
#  'must',
#  'stop',
#  'try',
#  'small',
#  'plates',
#  'specialty',
#  'cocktails',
#  'way',
#  'around',
#  'cultural',
#  'district',
#  'take',
#  'date',
#  'dinner',
#  'bloody',
#  'mary',
#  'bar',
#  'vodka',
#  'mean',
#  'best',
#  'sense',
#  'course',
#  'way',
#  'lenten',
#  'fridays',
#  'ribs',
#  'smoked',
#  'hours',
#  'hours',
#  'right',
#  'back',
#  'best',
#  'brunch',
#  'da',
#  'burgh',
#  'guys',
#  'fill',
#  'fast',
#  'gets',
#  'noisy',
#  'real',
#  'quick',
#  'make',
#  'reservation',
#  'go',
#  'early',
#  'great',
#  'drink',
#  'selection',
#  'unique',
#  'menu',
#  'om',
#  'nom',
#  'nom',
#  'quick',
#  'dinner',
#  'van',
#  'halen',
#  'love',
#  'bone',
#  'marrow',
#  'tartare',
#  'make',
#  'reservation',
#  'place',
#  'busy',
#  'even',
#  'sunday',
#  'night',
#  'probably',
#  'epic',
#  'bloody',
#  'mary',
#  'bar',
#  'time',
#  'oh',
#  'must',
#  'also',
#  'mention',
#  'one',
#  'bellinis',
#  'heard',
#  'lot',
#  'good',
#  'things',
#  'meeting',
#  'brother',
#  'sis',
#  'dinner',
#  'really',
#  'good',
#  'burger',
#  'bun',
#  'good',
#  'made',
#  'house',
#  'fries',
#  'excellent',
#  'av',
#  'wild',
#  'turkey',
#  'stout',
#  'yummy',
#  'convenient',
#  'street',
#  'garage',
#  'parking',
#  'around',
#  'corner',
#  'lunch',
#  'hours',
#  'start',
#  'pub',
#  'burger',
#  'france',
#  'short',
#  'rib',
#  'hash',
#  'irish',
#  'breakfast',
#  'tater',
#  'n',
#  'truffle',
#  'mayo',
#  'brunch',
#  'work',
#  'lunch',
#  'got',
#  'black',
#  'blue',
#  'burger',
#  'epic',
#  'sunday',
#  'brunch',
#  'love',
#  'place',
#  'sadly',
#  'brunch',
#  'least',
#  'favorite',
#  'visit',
#  'subpar',
#  'service',
#  'gnats',
#  'bloody',
#  'mary',
#  'bar',
#  'food',
#  'still',
#  'good',
#  'though',
#  'food',
#  'chart',
#  'tonight',
#  'try',
#  'old',
#  'school',
#  'cocktail',
#  'mmmmm',
#  'bone',
#  'marrow',
#  'charcuterie',
#  'taste',
#  'absinthe',
#  'trying',
#  'blood',
#  'sand',
#  'start',
#  'random',
#  'wifi',
#  'extremely',
#  'comfy',
#  'chairs',
#  'brunch',
#  'french',
#  'toast',
#  'cooked',
#  'well',
#  'banana',
#  'bread',
#  'beer',
#  'first',
#  'day',
#  'lunch',
#  'tequila',
#  'fizz',
#  'refreshing',
#  'serving',
#  'lunch',
#  'bloody',
#  'mary',
#  'bar',
#  'first',
#  'time',
#  'bloody',
#  'spent',
#  'oz',
#  'ribeye',
#  'flavor',
#  'wonder',
#  'steak',
#  'sauce',
#  'kinda',
#  'loud',
#  'apparently',
#  'need',
#  'reservations',
#  'weeks',
#  'advance',
#  'walked',
#  'need',
#  'fix',
#  'couch',
#  'dust',
#  'though',
#  'mussels',
#  'restaurant',
#  'week',
#  'brunch',
#  'linda',
#  'first',
#  'regular',
#  'lunch',
#  'customers',
#  'bartenders',
#  'make',
#  'excellent',
#  'beverages',
#  'oww',
#  'virtually',
#  'empty',
#  'sunday',
#  'brunch',
#  'taking',
#  'get',
#  'food',
#  'though',
#  'many',
#  'delicious',
#  'options',
#  'must',
#  'come',
#  'back',
#  'make',
#  'reservations',
#  'always',
#  'make',
#  'reservation',
#  'definitely',
#  'try',
#  'libations',
#  'amazing',
#  'bone',
#  'marrow',
#  'afraid',
#  'step',
#  'comfort',
#  'zone',
#  'give',
#  'deliciousness',
#  'try',
#  'longer',
#  'offering',
#  'lunch',
#  'weekdays',
#  'boom',
#  'service',
#  'really',
#  'gone',
#  'downhill',
#  'years',
#  'make',
#  'reservations',
#  'order',
#  'one',
#  'speciality',
#  'drinks',
#  'dinner',
#  'options',
#  'offer',
#  'variety',
#  'try',
#  'roasted',
#  'chicken',
#  'yum',
#  'buttermilk',
#  'fried',
#  'chicken',
#  'livers',
#  'oz',
#  'ribeye',
#  'bloody',
#  'mary',
#  'bar',
#  'brunch',
#  'great',
#  'vodka',
#  'tequila',
#  'infusion',
#  'options',
#  'pub',
#  'burger',
#  'anderson',
#  'hop',
#  'ottin',
#  'ipa',
#  'answer',
#  'favorite',
#  'drinking',
#  'eating',
#  'place',
#  'love',
#  'meat',
#  'potatoes',
#  'try',
#  'mac',
#  'cheese',
#  'ha',
#  'back',
#  'drinks',
#  'show',
#  'loud',
#  'night',
#  'date',
#  'lean',
#  'table',
#  'talk',
#  'quieted',
#  'around',
#  'though',
#  'awesome',
#  'food',
#  'truely',
#  'floored',
#  'get',
#  'delicious',
#  'sour',
#  'bar',
#  'great',
#  'fried',
#  'brussels',
#  'sprouts',
#  'trust',
#  'atmosphere',
#  'menu',
#  'unbeatable',
#  'youre',
#  'rugged',
#  'gentleman',
#  'inner',
#  'quote',
#  'like',
#  'going',
#  'go',
#  'home',
#  'back',
#  'mundane',
#  'life',
#  'want',
#  'live',
#  'eternity',
#  'ere',
#  'eating',
#  'bone',
#  'marrow',
#  'hip',
#  'trendy',
#  'always',
#  'mean',
#  'great',
#  'night',
#  'less',
#  'impressed',
#  'culinary',
#  'trickery',
#  'simple',
#  'better',
#  'would',
#  'thought',
#  'named',
#  'meat',
#  'potatoes',
#  'get',
#  'go',
#  'happy',
#  'hour',
#  'leave',
#  'dinner',
#  'get',
#  'bar',
#  'seat',
#  'wait',
#  'time',
#  'entertaining',
#  'cool',
#  'vibe',
#  'wow',
#  'hard',
#  'choose',
#  'meat',
#  'potatoes',
#  'tonight',
#  'back',
#  'smoked',
#  'wings',
#  'amendment',
#  'back',
#  'black',
#  'koozie',
#  'laughter',
#  'best',
#  'medicine',
#  'champagne',
#  'gets',
#  'job',
#  'done',
#  'faster',
#  'good',
#  'weekend',
#  'brunch',
#  'started',
#  'serving',
#  'lunch',
#  'fridays',
#  'though',
#  'chicken',
#  'waffles',
#  'peanut',
#  'butter',
#  'monkey',
#  'bread',
#  'bloody',
#  'mary',
#  'bar',
#  'best',
#  'fried',
#  'chicken',
#  'hands',
#  'come',
#  'bloody',
#  'mary',
#  'bar',
#  'eat',
#  'specials',
#  'always',
#  'great',
#  'make',
#  'sure',
#  'ya',
#  'call',
#  'reservation',
#  'went',
#  'wednesday',
#  'night',
#  'birthday',
#  'packed',
#  'glad',
#  'reservation',
#  'though',
#  'great',
#  'place',
#  'sunday',
#  'brunch',
#  'sat',
#  'bar',
#  'great',
#  'service',
#  'great',
#  'food',
#  'course',
#  'irish',
#  'breakfast',
#  'coffee',
#  'crazy',
#  'good',
#  'food',
#  'esp',
#  'foodies',
#  'crazy',
#  'good',
#  'see',
#  'cow',
#  'thanks',
#  'emily',
#  'brunch',
#  'drinks',
#  'favorite',
#  'place',
#  'birthday',
#  'celebration',
#  'love',
#  'adam',
#  'mike',
#  'fabulous',
#  'drinks',
#  'great',
#  'service',
#  'everytime',
#  'busy',
#  'gets',
#  'packed',
#  'quickly',
#  'find',
#  'good',
#  'seat',
#  'bar',
#  'call',
#  'amazing',
#  'brunch',
#  'amazing',
#  'brunch',
#  'lunch',
#  'dinner',
#  'cocktails',
#  'meat',
#  'potatoes',
#  'never',
#  'fails',
#  'turn',
#  'absinthe',
#  'fire',
#  'fathers',
#  'day',
#  'celebration',
#  'enjoying',
#  'bloody',
#  'mary',
#  'bar',
#  'unique',
#  'brunch',
#  'menu',
#  'good',
#  'good',
#  'place',
#  'hangout',
#  'tried',
#  'salmon',
#  'good',
#  'unlimited',
#  'bloody',
#  'mary',
#  'bar',
#  'pittsburgh',
#  'food',
#  'strangely',
#  'good',
#  'service',
#  'ok',
#  'make',
#  'sure',
#  'make',
#  'reservation',
#  'brunch',
#  'best',
#  'three',
#  'pigs',
#  'sandwich',
#  'must',
#  'try',
#  'make',
#  'reservation',
#  'brunch',
#  'twice',
#  'great',
#  'experience',
#  'times',
#  'talented',
#  'staff',
#  'fried',
#  'brussels',
#  'get',
#  'table',
#  'process',
#  'wack',
#  'way',
#  'engineered',
#  'especially',
#  'visible',
#  'tables',
#  'available',
#  'place',
#  'amazing',
#  'wings',
#  'pork',
#  'chop',
#  'dish',
#  'eye',
#  'popping',
#  'well',
#  'delicious',
#  'bring',
#  'empty',
#  'stomach',
#  'men',
#  'let',
#  'bartenders',
#  'hook',
#  'drinks',
#  'food',
#  'ye',
#  'shall',
#  'rewarded',
#  'brunch',
#  'wow',
#  'amazing',
#  'feels',
#  'fancy',
#  'yet',
#  'warm',
#  'comfy',
#  'without',
#  'redneck',
#  'like',
#  'back',
#  'home',
#  'deep',
#  'south',
#  'seriously',
#  'best',
#  'bbq',
#  'food',
#  'service',
#  'around',
#  'pittsburgh',
#  'love',
#  'people',
#  'food',
#  'thanks',
#  'wonderful',
#  'night',
#  'eclectic',
#  'menu',
#  'looks',
#  'fun',
#  'go',
#  'come',
#  'hungry',
#  'come',
#  'see',
#  'mike',
#  'bar',
#  'wizard',
#  'cocktails',
#  'inventive',
#  'menu',
#  'visited',
#  'craving',
#  'go',
#  'back',
#  'food',
#  'fantastic',
#  'place',
#  'amazing',
#  'eat',
#  'get',
#  'poutine',
#  'gluten',
#  'free',
#  'vegan',
#  'options',
#  'lenten',
#  'menu',
#  'love',
#  'places',
#  'atmosphere',
#  'thier',
#  'macaroni',
#  'cheese',
#  'get',
#  'bread',
#  'pudding',
#  'make',
#  'banana',
#  'bread',
#  'get',
#  'bone',
#  'marrow',
#  'big',
#  'enough',
#  'share',
#  'damn',
#  'old',
#  'fashioned',
#  'fresh',
#  'sgt',
#  'pepper',
#  'old',
#  'fashioned',
#  'get',
#  'yaaas',
#  'bourbon',
#  'oh',
#  'cocktails',
#  'love',
#  'decor',
#  'rustic',
#  'chic',
#  'pioneering',
#  'restaurant',
#  'inspiration',
#  'else',
#  'trendy',
#  'delicious',
#  'order',
#  'bone',
#  'marrow',
#  'idiot',
#  'food',
#  'amazing',
#  'flip',
#  'side',
#  'tiny',
#  'seating',
#  'almost',
#  'always',
#  'end',
#  'talking',
#  'neighbor',
#  'everything',
#  'delicious',
#  'wings',
#  'fried',
#  'brussel',
#  'sprouts',
#  'martini',
#  'good',
#  'atmosphere',
#  'great',
#  'bar',
#  'younger',
#  'hang',
#  'rudest',
#  'experience',
#  'bar',
#  'pittsburgh',
#  'ever',
#  'bartenders',
#  'mean',
#  'phenomenal',
#  'dinner',
#  'entrees',
#  'great',
#  'food',
#  'good',
#  'atmosphere',
#  'always',
#  'interesting',
#  'specials',
#  'consider',
#  'random',
#  'beer',
#  'selection',
#  'changes',
#  'daily',
#  'dine',
#  'outside',
#  'even',
#  'though',
#  'chilly',
#  'seat',
#  'small',
#  'blanket',
#  'help',
#  'warm',
#  'thoughtful',
#  'smoke',
#  'great',
#  'cocktail',
#  'brussel',
#  'sprouts',
#  'great',
#  'ordering',
#  'ribeye',
#  'people',
#  'suggest',
#  'ordering',
#  'anything',
#  'except',
#  'drinks',
#  'comes',
#  'piece',
#  'marrow',
#  'basically',
#  'comes',
#  'appetizer',
#  'brunch',
#  'salmon',
#  'flat',
#  'bread',
#  'ladies',
#  'try',
#  'black',
#  'dog',
#  'thank',
#  'later',
#  'bad',
#  'service',
#  'mediocre',
#  'food',
#  'would',
#  'never',
#  'waste',
#  'time',
#  'awesome',
#  'food',
#  'nuff',
#  'said',
#  'come',
#  'early',
#  'make',
#  'reservations',
#  'politely',
#  'ask',
#  'ribeye',
#  'everything',
#  'side',
#  'would',
#  'top',
#  'anything',
#  'surprises',
#  'guess',
#  'price',
#  'unaged',
#  'prime',
#  'try',
#  'bloody',
#  'mary',
#  'bar',
#  'make',
#  'reservations',
#  'early',
#  'bit',
#  'easier',
#  'get',
#  'table',
#  'weekend',
#  'come',
#  'grab',
#  'bar',
#  'seat',
#  'reservation',
#  'place',
#  'awesome',
#  'def',
#  'checking',
#  'yum',
#  'punch',
#  'fried',
#  'brussel',
#  'sprouts',
#  'steak',
#  'tartare',
#  'great',
#  'brunch',
#  'recommend',
#  'corned',
#  'beef',
#  'benedict',
#  'add',
#  'spice',
#  'bloody',
#  'mary',
#  'though',
#  'awesome',
#  'lunchtime',
#  'spot',
#  'great',
#  'atmosphere',
#  'huge',
#  'portions',
#  'visited',
#  'last',
#  'night',
#  'new',
#  'year',
#  'eve',
#  'ordered',
#  'fried',
#  'pickles',
#  'fave',
#  'took',
#  'almost',
#  'mins',
#  'waitress',
#  'also',
#  'offer',
#  'explanation',
#  'offer',
#  'refill',
#  'drinks',
#  'waited',
#  'table',
#  'next',
#  'us',
#  'ordered',
#  'well',
#  'delivered',
#  'mins',
#  'disappointed',
#  'place',
#  'looks',
#  'awesome',
#  'veuve',
#  'fried',
#  'pickles',
#  'hello',
#  'meat',
#  'potatoes',
#  'restaurant',
#  'please',
#  'add',
#  'seasoning',
#  'dishes',
#  'thank',
#  'worst',
#  'service',
#  'ever',
#  'totally',
#  'rude',
#  'staff',
#  'go',
#  'highly',
#  'overrated',
#  'great',
#  'mac',
#  'n',
#  'cheese',
#  'tuna',
#  'tacos',
#  'terribly',
#  'salty',
#  'inedible',
#  'salmon',
#  'cooked',
#  'perfectly',
#  'kimchi',
#  'took',
#  'away',
#  'flavor',
#  'soo',
#  'good',
#  'love',
#  'bone',
#  'marrow',
#  'yummmmm',
#  'deff',
#  'try',
#  'pittsburgh',
#  'tartare',
#  'favorite',
#  'appetizer',
#  'like',
#  'bone',
#  'marrow',
#  'however',
#  'add',
#  'thr',
#  'toppings',
#  'time',
#  'doesnt',
#  'make',
#  'enjoyable',
#  'better',
#  'pate',
#  'bit',
#  'sweet',
#  'taste',
#  'meat',
#  'potatoes',
#  'two',
#  'enough',
#  'ready',
#  'amazing',
#  'meal',
#  'extremely',
#  'tasty',
#  'cocktails',
#  'crammed',
#  'lot',
#  'tables',
#  'near',
#  'bar',
#  'area',
#  'make',
#  'reservation',
#  'eat',
#  'bar',
#  'bartenders',
#  'make',
#  'anything',
#  'drink',
#  'mean',
#  'anything',
#  ...]

# %%
# stem words use nltk packages
def stem(textname):
    ps = PorterStemmer() # define the function as ps
    for word in textname:
        stem = ps.stem(word)
        result = print(word + ":" + stem) # shows the original words and the stem words
    return result

# %%
# stem words of our text
# You can see some do a good job: fridays -> friday
# some do a poor job: fries -> fri, which change the meaning of the word
# That's why I didn't put stem into the function clean()
mp_clean = clean(mp)
stem(mp_clean)
# Out:
# think:think
# would:would
# need:need
# reservation:reserv
# sunday:sunday
# wrong:wrong
# foodie:foodi
# must:must
# stop:stop
# try:tri
# small:small
# plates:plate
# specialty:specialti
# cocktails:cocktail
# way:way
# around:around
# cultural:cultur
# district:district
# take:take
# date:date
# dinner:dinner
# bloody:bloodi
# mary:mari
# bar:bar
# vodka:vodka
# mean:mean
# best:best
# sense:sens
# course:cours
# way:way
# lenten:lenten
# fridays:friday
# ribs:rib
# smoked:smoke
# hours:hour
# hours:hour
# right:right
# back:back
# best:best
# brunch:brunch
# da:da
# burgh:burgh
# guys:guy
# fill:fill
# fast:fast
# gets:get
# noisy:noisi
# real:real
# quick:quick
# make:make
# reservation:reserv
# go:go
# early:earli
# great:great
# drink:drink
# selection:select
# unique:uniqu
# menu:menu
# om:om
# nom:nom
# nom:nom
# quick:quick
# dinner:dinner
# van:van
# halen:halen
# love:love
# bone:bone
# marrow:marrow
# tartare:tartar
# make:make
# reservation:reserv
# place:place
# busy:busi
# even:even
# sunday:sunday
# night:night
# probably:probabl
# epic:epic
# bloody:bloodi
# mary:mari
# bar:bar
# time:time
# oh:oh
# must:must
# also:also
# mention:mention
# one:one
# bellinis:bellini
# heard:heard
# lot:lot
# good:good
# things:thing
# meeting:meet
# brother:brother
# sis:si
# dinner:dinner
# really:realli
# good:good
# burger:burger
# bun:bun
# good:good
# made:made
# house:hous
# fries:fri
# excellent:excel
# av:av
# wild:wild
# turkey:turkey
# stout:stout
# yummy:yummi
# convenient:conveni
# street:street
# garage:garag
# parking:park
# around:around
# corner:corner
# lunch:lunch
# hours:hour
# start:start
# pub:pub
# burger:burger
# france:franc
# short:short
# rib:rib
# hash:hash
# irish:irish
# breakfast:breakfast
# tater:tater
# n:n
# truffle:truffl
# mayo:mayo
# brunch:brunch
# work:work
# lunch:lunch
# got:got
# black:black
# blue:blue
# burger:burger
# epic:epic
# sunday:sunday
# brunch:brunch
# love:love
# place:place
# sadly:sadli
# brunch:brunch
# least:least
# favorite:favorit
# visit:visit
# subpar:subpar
# service:servic
# gnats:gnat
# bloody:bloodi
# mary:mari
# bar:bar
# food:food
# still:still
# good:good
# though:though
# food:food
# chart:chart
# tonight:tonight
# try:tri
# old:old
# school:school
# cocktail:cocktail
# mmmmm:mmmmm
# bone:bone
# marrow:marrow
# charcuterie:charcuteri
# taste:tast
# absinthe:absinth
# trying:tri
# blood:blood
# sand:sand
# start:start
# random:random
# wifi:wifi
# extremely:extrem
# comfy:comfi
# chairs:chair
# brunch:brunch
# french:french
# toast:toast
# cooked:cook
# well:well
# banana:banana
# bread:bread
# beer:beer
# first:first
# day:day
# lunch:lunch
# tequila:tequila
# fizz:fizz
# refreshing:refresh
# serving:serv
# lunch:lunch
# bloody:bloodi
# mary:mari
# bar:bar
# first:first
# time:time
# bloody:bloodi
# spent:spent
# oz:oz
# ribeye:ribey
# flavor:flavor
# wonder:wonder
# steak:steak
# sauce:sauc
# kinda:kinda
# loud:loud
# apparently:appar
# need:need
# reservations:reserv
# weeks:week
# advance:advanc
# walked:walk
# need:need
# fix:fix
# couch:couch
# dust:dust
# though:though
# mussels:mussel
# restaurant:restaur
# week:week
# brunch:brunch
# linda:linda
# first:first
# regular:regular
# lunch:lunch
# customers:custom
# bartenders:bartend
# make:make
# excellent:excel
# beverages:beverag
# oww:oww
# virtually:virtual
# empty:empti
# sunday:sunday
# brunch:brunch
# taking:take
# get:get
# food:food
# though:though
# many:mani
# delicious:delici
# options:option
# must:must
# come:come
# back:back
# make:make
# reservations:reserv
# always:alway
# make:make
# reservation:reserv
# definitely:definit
# try:tri
# libations:libat
# amazing:amaz
# bone:bone
# marrow:marrow
# afraid:afraid
# step:step
# comfort:comfort
# zone:zone
# give:give
# deliciousness:delici
# try:tri
# longer:longer
# offering:offer
# lunch:lunch
# weekdays:weekday
# boom:boom
# service:servic
# really:realli
# gone:gone
# downhill:downhil
# years:year
# make:make
# reservations:reserv
# order:order
# one:one
# speciality:special
# drinks:drink
# dinner:dinner
# options:option
# offer:offer
# variety:varieti
# try:tri
# roasted:roast
# chicken:chicken
# yum:yum
# buttermilk:buttermilk
# fried:fri
# chicken:chicken
# livers:liver
# oz:oz
# ribeye:ribey
# bloody:bloodi
# mary:mari
# bar:bar
# brunch:brunch
# great:great
# vodka:vodka
# tequila:tequila
# infusion:infus
# options:option
# pub:pub
# burger:burger
# anderson:anderson
# hop:hop
# ottin:ottin
# ipa:ipa
# answer:answer
# favorite:favorit
# drinking:drink
# eating:eat
# place:place
# love:love
# meat:meat
# potatoes:potato
# try:tri
# mac:mac
# cheese:chees
# ha:ha
# back:back
# drinks:drink
# show:show
# loud:loud
# night:night
# date:date
# lean:lean
# table:tabl
# talk:talk
# quieted:quiet
# around:around
# though:though
# awesome:awesom
# food:food
# truely:trueli
# floored:floor
# get:get
# delicious:delici
# sour:sour
# bar:bar
# great:great
# fried:fri
# brussels:brussel
# sprouts:sprout
# trust:trust
# atmosphere:atmospher
# menu:menu
# unbeatable:unbeat
# youre:your
# rugged:rug
# gentleman:gentleman
# inner:inner
# quote:quot
# like:like
# going:go
# go:go
# home:home
# back:back
# mundane:mundan
# life:life
# want:want
# live:live
# eternity:etern
# ere:ere
# eating:eat
# bone:bone
# marrow:marrow
# hip:hip
# trendy:trendi
# always:alway
# mean:mean
# great:great
# night:night
# less:less
# impressed:impress
# culinary:culinari
# trickery:trickeri
# simple:simpl
# better:better
# would:would
# thought:thought
# named:name
# meat:meat
# potatoes:potato
# get:get
# go:go
# happy:happi
# hour:hour
# leave:leav
# dinner:dinner
# get:get
# bar:bar
# seat:seat
# wait:wait
# time:time
# entertaining:entertain
# cool:cool
# vibe:vibe
# wow:wow
# hard:hard
# choose:choos
# meat:meat
# potatoes:potato
# tonight:tonight
# back:back
# smoked:smoke
# wings:wing
# amendment:amend
# back:back
# black:black
# koozie:koozi
# laughter:laughter
# best:best
# medicine:medicin
# champagne:champagn
# gets:get
# job:job
# done:done
# faster:faster
# good:good
# weekend:weekend
# brunch:brunch
# started:start
# serving:serv
# lunch:lunch
# fridays:friday
# though:though
# chicken:chicken
# waffles:waffl
# peanut:peanut
# butter:butter
# monkey:monkey
# bread:bread
# bloody:bloodi
# mary:mari
# bar:bar
# best:best
# fried:fri
# chicken:chicken
# hands:hand
# come:come
# bloody:bloodi
# mary:mari
# bar:bar
# eat:eat
# specials:special
# always:alway
# great:great
# make:make
# sure:sure
# ya:ya
# call:call
# reservation:reserv
# went:went
# wednesday:wednesday
# night:night
# birthday:birthday
# packed:pack
# glad:glad
# reservation:reserv
# though:though
# great:great
# place:place
# sunday:sunday
# brunch:brunch
# sat:sat
# bar:bar
# great:great
# service:servic
# great:great
# food:food
# course:cours
# irish:irish
# breakfast:breakfast
# coffee:coffe
# crazy:crazi
# good:good
# food:food
# esp:esp
# foodies:foodi
# crazy:crazi
# good:good
# see:see
# cow:cow
# thanks:thank
# emily:emili
# brunch:brunch
# drinks:drink
# favorite:favorit
# place:place
# birthday:birthday
# celebration:celebr
# love:love
# adam:adam
# mike:mike
# fabulous:fabul
# drinks:drink
# great:great
# service:servic
# everytime:everytim
# busy:busi
# gets:get
# packed:pack
# quickly:quickli
# find:find
# good:good
# seat:seat
# bar:bar
# call:call
# amazing:amaz
# brunch:brunch
# amazing:amaz
# brunch:brunch
# lunch:lunch
# dinner:dinner
# cocktails:cocktail
# meat:meat
# potatoes:potato
# never:never
# fails:fail
# turn:turn
# absinthe:absinth
# fire:fire
# fathers:father
# day:day
# celebration:celebr
# enjoying:enjoy
# bloody:bloodi
# mary:mari
# bar:bar
# unique:uniqu
# brunch:brunch
# menu:menu
# good:good
# good:good
# place:place
# hangout:hangout
# tried:tri
# salmon:salmon
# good:good
# unlimited:unlimit
# bloody:bloodi
# mary:mari
# bar:bar
# pittsburgh:pittsburgh
# food:food
# strangely:strang
# good:good
# service:servic
# ok:ok
# make:make
# sure:sure
# make:make
# reservation:reserv
# brunch:brunch
# best:best
# three:three
# pigs:pig
# sandwich:sandwich
# must:must
# try:tri
# make:make
# reservation:reserv
# brunch:brunch
# twice:twice
# great:great
# experience:experi
# times:time
# talented:talent
# staff:staff
# fried:fri
# brussels:brussel
# get:get
# table:tabl
# process:process
# wack:wack
# way:way
# engineered:engin
# especially:especi
# visible:visibl
# tables:tabl
# available:avail
# place:place
# amazing:amaz
# wings:wing
# pork:pork
# chop:chop
# dish:dish
# eye:eye
# popping:pop
# well:well
# delicious:delici
# bring:bring
# empty:empti
# stomach:stomach
# men:men
# let:let
# bartenders:bartend
# hook:hook
# drinks:drink
# food:food
# ye:ye
# shall:shall
# rewarded:reward
# brunch:brunch
# wow:wow
# amazing:amaz
# feels:feel
# fancy:fanci
# yet:yet
# warm:warm
# comfy:comfi
# without:without
# redneck:redneck
# like:like
# back:back
# home:home
# deep:deep
# south:south
# seriously:serious
# best:best
# bbq:bbq
# food:food
# service:servic
# around:around
# pittsburgh:pittsburgh
# love:love
# people:peopl
# food:food
# thanks:thank
# wonderful:wonder
# night:night
# eclectic:eclect
# menu:menu
# looks:look
# fun:fun
# go:go
# come:come
# hungry:hungri
# come:come
# see:see
# mike:mike
# bar:bar
# wizard:wizard
# cocktails:cocktail
# inventive:invent
# menu:menu
# visited:visit
# craving:crave
# go:go
# back:back
# food:food
# fantastic:fantast
# place:place
# amazing:amaz
# eat:eat
# get:get
# poutine:poutin
# gluten:gluten
# free:free
# vegan:vegan
# options:option
# lenten:lenten
# menu:menu
# love:love
# places:place
# atmosphere:atmospher
# thier:thier
# macaroni:macaroni
# cheese:chees
# get:get
# bread:bread
# pudding:pud
# make:make
# banana:banana
# bread:bread
# get:get
# bone:bone
# marrow:marrow
# big:big
# enough:enough
# share:share
# damn:damn
# old:old
# fashioned:fashion
# fresh:fresh
# sgt:sgt
# pepper:pepper
# old:old
# fashioned:fashion
# get:get
# yaaas:yaaa
# bourbon:bourbon
# oh:oh
# cocktails:cocktail
# love:love
# decor:decor
# rustic:rustic
# chic:chic
# pioneering:pioneer
# restaurant:restaur
# inspiration:inspir
# else:els
# trendy:trendi
# delicious:delici
# order:order
# bone:bone
# marrow:marrow
# idiot:idiot
# food:food
# amazing:amaz
# flip:flip
# side:side
# tiny:tini
# seating:seat
# almost:almost
# always:alway
# end:end
# talking:talk
# neighbor:neighbor
# everything:everyth
# delicious:delici
# wings:wing
# fried:fri
# brussel:brussel
# sprouts:sprout
# martini:martini
# good:good
# atmosphere:atmospher
# great:great
# bar:bar
# younger:younger
# hang:hang
# rudest:rudest
# experience:experi
# bar:bar
# pittsburgh:pittsburgh
# ever:ever
# bartenders:bartend
# mean:mean
# phenomenal:phenomen
# dinner:dinner
# entrees:entre
# great:great
# food:food
# good:good
# atmosphere:atmospher
# always:alway
# interesting:interest
# specials:special
# consider:consid
# random:random
# beer:beer
# selection:select
# changes:chang
# daily:daili
# dine:dine
# outside:outsid
# even:even
# though:though
# chilly:chilli
# seat:seat
# small:small
# blanket:blanket
# help:help
# warm:warm
# thoughtful:thought
# smoke:smoke
# great:great
# cocktail:cocktail
# brussel:brussel
# sprouts:sprout
# great:great
# ordering:order
# ribeye:ribey
# people:peopl
# suggest:suggest
# ordering:order
# anything:anyth
# except:except
# drinks:drink
# comes:come
# piece:piec
# marrow:marrow
# basically:basic
# comes:come
# appetizer:appet
# brunch:brunch
# salmon:salmon
# flat:flat
# bread:bread
# ladies:ladi
# try:tri
# black:black
# dog:dog
# thank:thank
# later:later
# bad:bad
# service:servic
# mediocre:mediocr
# food:food
# would:would
# never:never
# waste:wast
# time:time
# awesome:awesom
# food:food
# nuff:nuff
# said:said
# come:come
# early:earli
# make:make
# reservations:reserv
# politely:polit
# ask:ask
# ribeye:ribey
# everything:everyth
# side:side
# would:would
# top:top
# anything:anyth
# surprises:surpris
# guess:guess
# price:price
# unaged:unag
# prime:prime
# try:tri
# bloody:bloodi
# mary:mari
# bar:bar
# make:make
# reservations:reserv
# early:earli
# bit:bit
# easier:easier
# get:get
# table:tabl
# weekend:weekend
# come:come
# grab:grab
# bar:bar
# seat:seat
# reservation:reserv
# place:place
# awesome:awesom
# def:def
# checking:check
# yum:yum
# punch:punch
# fried:fri
# brussel:brussel
# sprouts:sprout
# steak:steak
# tartare:tartar
# great:great
# brunch:brunch
# recommend:recommend
# corned:corn
# beef:beef
# benedict:benedict
# add:add
# spice:spice
# bloody:bloodi
# mary:mari
# though:though
# awesome:awesom
# lunchtime:lunchtim
# spot:spot
# great:great
# atmosphere:atmospher
# huge:huge
# portions:portion
# visited:visit
# last:last
# night:night
# new:new
# year:year
# eve:eve
# ordered:order
# fried:fri
# pickles:pickl
# fave:fave
# took:took
# almost:almost
# mins:min
# waitress:waitress
# also:also
# offer:offer
# explanation:explan
# offer:offer
# refill:refil
# drinks:drink
# waited:wait
# table:tabl
# next:next
# us:us
# ordered:order
# well:well
# delivered:deliv
# mins:min
# disappointed:disappoint
# place:place
# looks:look
# awesome:awesom
# veuve:veuv
# fried:fri
# pickles:pickl
# hello:hello
# meat:meat
# potatoes:potato
# restaurant:restaur
# please:pleas
# add:add
# seasoning:season
# dishes:dish
# thank:thank
# worst:worst
# service:servic
# ever:ever
# totally:total
# rude:rude
# staff:staff
# go:go
# highly:highli
# overrated:overr
# great:great
# mac:mac
# n:n
# cheese:chees
# tuna:tuna
# tacos:taco
# terribly:terribl
# salty:salti
# inedible:ined
# salmon:salmon
# cooked:cook
# perfectly:perfectli
# kimchi:kimchi
# took:took
# away:away
# flavor:flavor
# soo:soo
# good:good
# love:love
# bone:bone
# marrow:marrow
# yummmmm:yummmmm
# deff:deff
# try:tri
# pittsburgh:pittsburgh
# tartare:tartar
# favorite:favorit
# appetizer:appet
# like:like
# bone:bone
# marrow:marrow
# however:howev
# add:add
# thr:thr
# toppings:top
# time:time
# doesnt:doesnt
# make:make
# enjoyable:enjoy
# better:better
# pate:pate
# bit:bit
# sweet:sweet
# taste:tast
# meat:meat
# potatoes:potato
# two:two
# enough:enough
# ready:readi
# amazing:amaz
# meal:meal
# extremely:extrem
# tasty:tasti
# cocktails:cocktail
# crammed:cram
# lot:lot
# tables:tabl
# near:near
# bar:bar
# area:area
# make:make
# reservation:reserv
# eat:eat
# bar:bar
# bartenders:bartend
# make:make
# anything:anyth
# drink:drink
# mean:mean
# anything:anyth
# absinthe:absinth
# amazing:amaz
# steak:steak
# sitting:sit
# bar:bar
# wave:wave
# arm:arm
# acknowledge:acknowledg
# presence:presenc
# p:p
# gotten:gotten
# cocky:cocki
# full:full
# great:great
# service:servic
# pot:pot
# roast:roast
# incredible:incred
# pork:pork
# belly:belli
# tacos:taco
# bartenders:bartend
# could:could
# much:much
# friendlier:friendlier
# make:make
# reservations:reserv
# see:see
# check:check
# comments:comment
# amazing:amaz
# food:food
# good:good
# service:servic
# definitely:definit
# coming:come
# back:back
# best:best
# caesar:caesar
# salad:salad
# food:food
# lukewarm:lukewarm
# tasted:tast
# sensational:sensat
# great:great
# food:food
# avoid:avoid
# busy:busi
# times:time
# friday:friday
# saturday:saturday
# nights:night
# wait:wait
# staff:staff
# gets:get
# overwhelmed:overwhelm
# easily:easili
# service:servic
# goes:goe
# downhill:downhil
# seriously:serious
# great:great
# food:food
# bar:bar
# area:area
# service:servic
# much:much
# better:better
# bartenders:bartend
# versus:versu
# section:section
# waiters:waiter
# nice:nice
# atmosphere:atmospher
# although:although
# tight:tight
# quarters:quarter
# food:food
# drinks:drink
# great:great
# says:say
# name:name
# well:well
# stellar:stellar
# steak:steak
# friendly:friendli
# service:servic
# highly:highli
# recommend:recommend
# short:short
# ribs:rib
# try:tri
# tomahawk:tomahawk
# ribeye:ribey
# best:best
# steak:steak
# america:america
# nice:nice
# fusion:fusion
# cuisine:cuisin
# bibimbap:bibimbap
# must:must
# see:see
# check:check
# comment:comment
# busy:busi
# place:place
# make:make
# reservation:reserv
# duck:duck
# though:though
# worth:worth
# blown:blown
# paycheck:paycheck
# tomahawk:tomahawk
# pastrami:pastrami
# rubbed:rub
# pork:pork
# belly:belli
# love:love
# place:place
# chicken:chicken
# livers:liver
# outstanding:outstand
# bone:bone
# marrow:marrow
# must:must
# always:alway
# great:great
# valet:valet
# parking:park
# chicken:chicken
# waffles:waffl
# lunch:lunch
# menu:menu
# atmospherically:atmospher
# prepared:prepar
# feel:feel
# like:like
# eating:eat
# middle:middl
# hollister:hollist
# retail:retail
# store:store
# brain:brain
# thumping:thump
# bass:bass
# mindless:mindless
# house:hous
# music:music
# background:background
# tad:tad
# much:much
# sunday:sunday
# brunch:brunch
# really:realli
# good:good
# drinks:drink
# probably:probabl
# best:best
# mussels:mussel
# town:town
# little:littl
# wait:wait
# outstanding:outstand
# food:food
# eat:eat
# meat:meat
# potatos:potato
# pittsburgh:pittsburgh
# staff:staff
# rude:rude
# started:start
# rude:rude
# bartender:bartend
# softened:soften
# bit:bit
# seriously:serious
# pittsburgh:pittsburgh
# never:never
# change:chang
# another:anoth
# pig:pig
# lipstick:lipstick
# meat:meat
# potatoes:potato
# two:two
# changes:chang
# lives:live
# love:love
# dream:dream
# cheese:chees
# plate:plate
# cxc:cxc
# aallyl:aallyl
# always:alway
# make:make
# stop:stop
# great:great
# late:late
# night:night
# eats:eat
# cool:cool
# space:space
# fun:fun
# vibe:vibe
# thai:thai
# steak:steak
# salad:salad
# delish:delish
# service:servic
# pleasant:pleasant
# one:one
# favorite:favorit
# places:place
# great:great
# service:servic
# amazing:amaz
# food:food
# brunch:brunch
# spectacular:spectacular
# bloody:bloodi
# marries:marri
# even:even
# better:better
# order:order
# chicken:chicken
# waffles:waffl
# brunch:brunch
# plan:plan
# eating:eat
# rest:rest
# day:day
# favorite:favorit
# restaurant:restaur
# pittsburgh:pittsburgh
# great:great
# go:go
# spot:spot
# always:alway
# point:point
# great:great
# drinks:drink
# burger:burger
# one:one
# best:best
# ever:ever
# always:alway
# meal:meal
# never:never
# disappoints:disappoint
# place:place
# outstanding:outstand
# great:great
# atmosphere:atmospher
# food:food
# superb:superb
# food:food
# great:great
# atmosphere:atmospher
# kept:kept
# another:anoth
# drink:drink
# special:special
# yellow:yellow
# tomato:tomato
# gazpacho:gazpacho
# blue:blue
# crab:crab
# outstanding:outstand
# liked:like
# much:much
# bowl:bowl
# appetizer:appet
# another:anoth
# dinner:dinner
# bravo:bravo
# chef:chef
# great:great
# meat:meat
# appetizers:appet
# love:love
# drinks:drink
# good:good
# place:place
# go:go
# theater:theater

# %% [markdown]
# ### Part 3. Create word cloud

# %%
# check the type of mp_clean
type(mp_clean)
# Out:
# list

# %%
# convert List into String, we use join(), " ": use space to seperate the words
# we need string type of text to create word cloud
new = " ".join(mp_clean)
print(new)
# Out:
# think would need reservation sunday wrong foodie must stop try small plates specialty cocktails way around cultural district take date dinner bloody mary bar vodka mean best sense course way lenten fridays ribs smoked hours hours right back best brunch da burgh guys fill fast gets noisy real quick make reservation go early great drink selection unique menu om nom nom quick dinner van halen love bone marrow tartare make reservation place busy even sunday night probably epic bloody mary bar time oh must also mention one bellinis heard lot good things meeting brother sis dinner really good burger bun good made house fries excellent av wild turkey stout yummy convenient street garage parking around corner lunch hours start pub burger france short rib hash irish breakfast tater n truffle mayo brunch work lunch got black blue burger epic sunday brunch love place sadly brunch least favorite visit subpar service gnats bloody mary bar food still good though food chart tonight try old school cocktail mmmmm bone marrow charcuterie taste absinthe trying blood sand start random wifi extremely comfy chairs brunch french toast cooked well banana bread beer first day lunch tequila fizz refreshing serving lunch bloody mary bar first time bloody spent oz ribeye flavor wonder steak sauce kinda loud apparently need reservations weeks advance walked need fix couch dust though mussels restaurant week brunch linda first regular lunch customers bartenders make excellent beverages oww virtually empty sunday brunch taking get food though many delicious options must come back make reservations always make reservation definitely try libations amazing bone marrow afraid step comfort zone give deliciousness try longer offering lunch weekdays boom service really gone downhill years make reservations order one speciality drinks dinner options offer variety try roasted chicken yum buttermilk fried chicken livers oz ribeye bloody mary bar brunch great vodka tequila infusion options pub burger anderson hop ottin ipa answer favorite drinking eating place love meat potatoes try mac cheese ha back drinks show loud night date lean table talk quieted around though awesome food truely floored get delicious sour bar great fried brussels sprouts trust atmosphere menu unbeatable youre rugged gentleman inner quote like going go home back mundane life want live eternity ere eating bone marrow hip trendy always mean great night less impressed culinary trickery simple better would thought named meat potatoes get go happy hour leave dinner get bar seat wait time entertaining cool vibe wow hard choose meat potatoes tonight back smoked wings amendment back black koozie laughter best medicine champagne gets job done faster good weekend brunch started serving lunch fridays though chicken waffles peanut butter monkey bread bloody mary bar best fried chicken hands come bloody mary bar eat specials always great make sure ya call reservation went wednesday night birthday packed glad reservation though great place sunday brunch sat bar great service great food course irish breakfast coffee crazy good food esp foodies crazy good see cow thanks emily brunch drinks favorite place birthday celebration love adam mike fabulous drinks great service everytime busy gets packed quickly find good seat bar call amazing brunch amazing brunch lunch dinner cocktails meat potatoes never fails turn absinthe fire fathers day celebration enjoying bloody mary bar unique brunch menu good good place hangout tried salmon good unlimited bloody mary bar pittsburgh food strangely good service ok make sure make reservation brunch best three pigs sandwich must try make reservation brunch twice great experience times talented staff fried brussels get table process wack way engineered especially visible tables available place amazing wings pork chop dish eye popping well delicious bring empty stomach men let bartenders hook drinks food ye shall rewarded brunch wow amazing feels fancy yet warm comfy without rednec ...

# %%
# generate wordcloud (wc) for the text file
# more info about wordcloud:
# https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

def create_wordcloud(text):
    # I want the wordcloud to be a certain shape, here is the cow shape
    # read the background image:
    pic = imageio.imread('cow.jpg') 
    wc_text = WordCloud(mask=pic, # give a binary mask on where to draw word
                        background_color="white", # background color is white
                        scale=10,  # to make the words clearer and make the graph bigger in the .jpg file
                        stopwords=STOPWORDS # remove the build-in stopwords such as these, here, how, can, me, etc.
                                            # If None, the build-in STOPWORDS list will be used.
                        ).generate(text) # generate the word cloud
    pic_colors = ImageColorGenerator(pic) # create coloring from image
    plt.axis('off')  # remove the axes in the wc_text because the original word cloud comes with the axes
    plt.imshow(wc_text) # show the word cloud graph wc_text
    wc_text.to_file('wc.jpg') #save wordcloud graph wc_text to jpg file in your directory

# %%
# creat word cloud for the text
# Please check your directory, and find a wc.jpg that is larger and clearer
# From the graph, we can learn that the resturant is a great place, and especially good for brunch and drink
create_wordcloud(new)
